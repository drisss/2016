# %%
import json
import os.path

# %%
PATH = os.path.expanduser("~/github/HackaTAL2016/Tweets/Matchs/train_euro2016/Groupe_A/fr/")
FILE = "Albanie_Suisse_2016-06-11_15h_fr.json"
# PATH = os.path.expanduser("~/github/HackaTAL2016_mev/Tweets/Medias/")
# FILE = "le_Parisien.json"
os.path.isfile(os.path.join(PATH, FILE))
# Out:
# True

# %%
tweets = []
for line in open(os.path.join(PATH, FILE)):
    tweets.append(json.loads(line))
    
# with open(os.path.join(PATH, FILE)) as data_f:
#     for line in data_txt:
#         print(line)
# Out:
# {"contributors": null,"coordinates": null,"created_at": "Sat Jun 11 12:59:59 +0000 2016","entities": {"hashtags": [],"symbols": [],"urls": [{"display_url": "vine.co/v/iL7Ivg0UedQ","expanded_url": "https://vine.co/v/iL7Ivg0UedQ","indices": [59,82],"url": "https://t.co/aCQ9wnwTie"}],"user_mentions": [{"id": 2806172551,"id_str": "2806172551","indices": [3,12],"name": "pq j'suis en S ?","screen_name": "cvrentin"}]},"favorite_count": 0,"favorited": false,"filter_level": "low","geo": null,"id": 741615967298584577,"id_str": "741615967298584577","in_reply_to_screen_name": null,"in_reply_to_status_id": null,"in_reply_to_status_id_str": null,"in_reply_to_user_id": null,"in_reply_to_user_id_str": null,"is_quote_status": false,"lang": "fr","place": null,"possibly_sensitive": false,"retweet_count": 0,"retweeted": false,"retweeted_status": {"contributors": null,"coordinates": null,"created_at": "Sat Jun 11 12:58:12 +0000 2016","entities": {"hashtags": [],"symbols": [],"urls": [{"display_url": "vin
# ...

# %%
print(tweets[0])
# Out:
# {'id': 741615967298584577, 'coordinates': None, 'is_quote_status': False, 'possibly_sensitive': False, 'in_reply_to_status_id_str': None, 'text': 'RT @cvrentin: regardez la fierté dans ses yeux à la fin 😭😭 https://t.co/aCQ9wnwTie', 'contributors': None, 'favorited': False, 'in_reply_to_user_id_str': None, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'timestamp_ms': '1465649999819', 'in_reply_to_user_id': None, 'retweeted': False, 'retweet_count': 0, 'truncated': False, 'lang': 'fr', 'entities': {'symbols': [], 'urls': [{'display_url': 'vine.co/v/iL7Ivg0UedQ', 'url': 'https://t.co/aCQ9wnwTie', 'indices': [59, 82], 'expanded_url': 'https://vine.co/v/iL7Ivg0UedQ'}], 'user_mentions': [{'id': 2806172551, 'screen_name': 'cvrentin', 'name': "pq j'suis en S ?", 'indices': [3, 12], 'id_str': '2806172551'}], 'hashtags': []}, 'filter_level': 'low', 'user': {'follow_request_sent': None, 'id': 2740083023, 'profile_background_image_url_https': 'ht
# ...

# %%
tweets[0]['created_at']
# Out:
# 'Sat Jun 11 12:59:59 +0000 2016'

# %%
for l in tweets[0:10]:
    print(l)
# Out:
# id
# coordinates
# is_quote_status
# possibly_sensitive
# in_reply_to_status_id_str
# text
# contributors
# favorited
# in_reply_to_user_id_str
# source
# timestamp_ms
# in_reply_to_user_id
# retweeted
# retweet_count
# truncated
# lang
# entities
# filter_level
# user
# geo
# id_str
# place
# created_at
# in_reply_to_status_id
# favorite_count
# in_reply_to_screen_name
# retweeted_status

# %%
with open(os.path.join(PATH, FILE)) as data_f:
#     data_txt = data_f.readlines()
    data = json.load(data_f)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-20-3f1dfec05cd4> in <module>()
#       1 with open(os.path.join(PATH, FILE)) as data_f:
#       2 #     data_txt = data_f.readlines()
# ----> 3     data = json.load(data_f)
#
# /Users/mev/anaconda/envs/nlp/lib/python3.5/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     266         cls=cls, object_hook=object_hook,
#     267         parse_float=parse_float, parse_int=parse_int,
# --> 268         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     269
#     270
#
# /Users/mev/anaconda/envs/nlp/lib/python3.5/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
# ...

# %%
print(data_txt)
# Out:
# ['{\n', '  "user": {\n', '    "verified": true,\n', '    "utc_offset": 7200,\n', '    "url": "http://www.leparisien.fr",\n', '    "time_zone": "Paris",\n', '    "statuses_count": 160810,\n', '    "listed_count": 6570,\n', '    "lang": "fr",\n', '    "is_translator": false,\n', '    "id_str": "38142665",\n', '    "id": 38142665,\n', '    "geo_enabled": false,\n', '    "friends_count": 820,\n', '    "following": null,\n', '    "contributors_enabled": false,\n', '    "created_at": "Wed May 06 08:50:13 +0000 2009",\n', '    "default_profile": false,\n', '    "default_profile_image": false,\n', '    "description": "Le Parisien-Aujourd\'hui en France, 1er quotidien généraliste de France",\n', '    "favourites_count": 263,\n', '    "follow_request_sent": null,\n', '    "followers_count": 1541365,\n', '    "location": null,\n', '    "name": "Le Parisien",\n', '    "notifications": null,\n', '    "profile_background_color": "0A506E",\n', '    "profile_background_image_url": "http://pbs.twimg.
# ...
